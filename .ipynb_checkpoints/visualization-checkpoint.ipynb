# %%
import pandas as pd
import time

while True:
    df = pd.read_csv('data/top_rated.csv',
                     header=None,
                     names=['order_id', 'pos_cot']) \
           .drop_duplicates(subset=['order_id'], keep='last')
    print(df.sort_values(by='pos_cot', ascending=False).head(10))
    print("===============================")
    time.sleep(10)
# Out:
# Empty DataFrame
# Columns: [order_id, pos_cot]
# Index: []
# ...
# Empty DataFrame
# Columns: [order_id, pos_cot]
# Index: []
# ...
# Empty DataFrame
# Columns: [order_id, pos_cot]
# Index: []
# ...
#                            order_id  pos_cot
# 0  809a282bbd5dbcabb6f2f724fca862ec        1
# ...
#                            order_id  pos_cot
# 0  809a282bbd5dbcabb6f2f724fca862ec        1
# 1  bfbd0f9bdef84302105ad712db648a6c        1
# 2  e5215415bb6f76fe3b7cb68103a0d1c0        1
# ...
#                             order_id  pos_cot
# 0   809a282bbd5dbcabb6f2f724fca862ec        1
# 16  5c5c9fde60ffb741545cf2608e8c12ca        1
# 58  cbbb524a0e1646aa6cf7a3c0bbe517ad        1
# 51  e439ced3d48f1a77f6ecc029cc946a6f        1
# 50  14b01335f19b97fce1437168032ae388        1
# 37  5cd498954e2b37d71b315166809b4bd7        1
# 36  59e7ca596664da0a459a145eb95cc9c5        1
# 32  9aa3197e4887919fde0307fc23601d7a        1
# 1   bfbd0f9bdef84302105ad712db648a6c        1
# 23  517e0a52c193102990befc46a5c5245a        1
# ...
